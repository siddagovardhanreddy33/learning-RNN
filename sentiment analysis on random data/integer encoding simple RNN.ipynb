# %%
print('hello world')
# Out:
# hello world

# %%
import numpy as np
import pandas as pd

# %%
docs = ['go india',
        'india india',
        'hip hip hurry',
        'jeethaga bhai jeethaga india jeethega',
        'bharat mata ki jai',
        'sachin sachin',
        'kohli kohli',
        'sachin sachin',
        'dhoni dhoni',
        'modi ji ki jai',
        'inquilab zindabad']

docs
# Out:
# ['go india',
#  'india india',
#  'hip hip hurry',
#  'jeethaga bhai jeethaga india jeethega',
#  'bharat mata ki jai',
#  'sachin sachin',
#  'kohli kohli',
#  'sachin sachin',
#  'dhoni dhoni',
#  'modi ji ki jai',
#  'inquilab zindabad']

# %% [markdown]
# ### integer encoding

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
Tokenizer = Tokenizer(oov_token='<nothing>')
Tokenizer

# %%
Tokenizer.fit_on_texts(docs)

# %%
Tokenizer.word_index
# Out:
# {'<nothing>': 1,
#  'india': 2,
#  'sachin': 3,
#  'hip': 4,
#  'jeethaga': 5,
#  'ki': 6,
#  'jai': 7,
#  'kohli': 8,
#  'dhoni': 9,
#  'go': 10,
#  'hurry': 11,
#  'bhai': 12,
#  'jeethega': 13,
#  'bharat': 14,
#  'mata': 15,
#  'modi': 16,
#  'ji': 17,
#  'inquilab': 18,
#  'zindabad': 19}

# %%
Tokenizer.word_counts
# Out:
# OrderedDict([('go', 1),
#              ('india', 4),
#              ('hip', 2),
#              ('hurry', 1),
#              ('jeethaga', 2),
#              ('bhai', 1),
#              ('jeethega', 1),
#              ('bharat', 1),
#              ('mata', 1),
#              ('ki', 2),
#              ('jai', 2),
#              ('sachin', 4),
#              ('kohli', 2),
#              ('dhoni', 2),
#              ('modi', 1),
#              ('ji', 1),
#              ('inquilab', 1),
#              ('zindabad', 1)])

# %%
sequences = Tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[10, 2],
#  [2, 2],
#  [4, 4, 11],
#  [5, 12, 5, 2, 13],
#  [14, 15, 6, 7],
#  [3, 3],
#  [8, 8],
#  [3, 3],
#  [9, 9],
#  [16, 17, 6, 7],
#  [18, 19]]

# %%
## Padding

from keras.utils import pad_sequences

# %%
sequences = pad_sequences(sequences , padding='post')
sequences
# Out:
# array([[10,  2,  0,  0,  0],
#        [ 2,  2,  0,  0,  0],
#        [ 4,  4, 11,  0,  0],
#        [ 5, 12,  5,  2, 13],
#        [14, 15,  6,  7,  0],
#        [ 3,  3,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [ 3,  3,  0,  0,  0],
#        [ 9,  9,  0,  0,  0],
#        [16, 17,  6,  7,  0],
#        [18, 19,  0,  0,  0]], dtype=int32)

# %%
## sequence to vectors

# %% [markdown]
# ### Embaedding encoding

# %%
docs
# Out:
# ['go india',
#  'india india',
#  'hip hip hurry',
#  'jeethaga bhai jeethaga india jeethega',
#  'bharat mata ki jai',
#  'sachin sachin',
#  'kohli kohli',
#  'sachin sachin',
#  'dhoni dhoni',
#  'modi ji ki jai',
#  'inquilab zindabad']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
Tokenizer = Tokenizer()

# %%
Tokenizer.fit_on_texts(docs)

# %%
Tokenizer.word_index
# Out:
# {'india': 1,
#  'sachin': 2,
#  'hip': 3,
#  'jeethaga': 4,
#  'ki': 5,
#  'jai': 6,
#  'kohli': 7,
#  'dhoni': 8,
#  'go': 9,
#  'hurry': 10,
#  'bhai': 11,
#  'jeethega': 12,
#  'bharat': 13,
#  'mata': 14,
#  'modi': 15,
#  'ji': 16,
#  'inquilab': 17,
#  'zindabad': 18}

# %%
len(Tokenizer.word_index)
# Out:
# 18

# %%
sequences = Tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[9, 1],
#  [1, 1],
#  [3, 3, 10],
#  [4, 11, 4, 1, 12],
#  [13, 14, 5, 6],
#  [2, 2],
#  [7, 7],
#  [2, 2],
#  [8, 8],
#  [15, 16, 5, 6],
#  [17, 18]]

# %%
from keras.utils import  pad_sequences
sequences = pad_sequences(sequences , padding='post')
sequences
# Out:
# array([[ 9,  1,  0,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 3,  3, 10,  0,  0],
#        [ 4, 11,  4,  1, 12],
#        [13, 14,  5,  6,  0],
#        [ 2,  2,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 2,  2,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [15, 16,  5,  6,  0],
#        [17, 18,  0,  0,  0]], dtype=int32)

# %%
from keras import Sequential
from keras.layers import Dense , SimpleRNN , Embedding , Flatten

model = Sequential()
model.add(Embedding(17 , output_dim=2 , input_length=5))
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam','accurecy')

# %%
pred = model.predict(sequences)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 pred = model.predict(sequences)
#
# File c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sequential_1_1/embedding_1_1/GatherV2 defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 645, in run_forever
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 1999, in _run_once
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#
#   File "C:\Users\sidda\AppData\Local\Temp\ipykernel_23144\2398912789.py", line 1, in <module>
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 588, in predict
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 282, in one_step_on_data_distributed
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 125, in wrapper
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 271, in one_step_on_data
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 110, in predict_step
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\layer.py", line 998, in __call__
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\ops\operation.py", line 59, in __call__
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\sequential.py", line 239, in call
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\functional.py", line 183, in call
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\ops\function.py", line 210, in _run_through_graph
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\functional.py", line 695, in call
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\layer.py", line 998, in __call__
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\ops\operation.py", line 59, in __call__
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py", line 169, in call
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\ops\numpy.py", line 7613, in take
#
#   File "c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\numpy.py", line 3015, in take
#
# indices[10,0] = 17 is not in [0, 17)
# 	 [[{{node sequential_1_1/embedding_1_1/GatherV2}}]] [Op:__inference_one_step_on_data_distributed_373]
